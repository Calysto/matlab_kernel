# %%
t = linspace(0,6*pi,100);
plot(sin(t))
grid on
hold on
plot(cos(t), 'r')

# %%
b = 10*cos(t)+30; plot(b); grid on

# %%
a = [1,2,3]
# Out:
# a =
#
#      1     2     3

# %%
b = a + 3;

# %%
disp(b)
# Out:
# 4     5     6
